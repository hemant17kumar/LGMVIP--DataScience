# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/photo-1517336714731-489689fd1ca8.jfif')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x800 at 0x7F28A9EEFED0>

# %%
gray_image=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=1000x800 at 0x7F28A85DA610>

# %%
gray_image=255-gray_image
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=1000x800 at 0x7F28A85D4E50>

# %%
gray_image=255-gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=1000x800 at 0x7F28A85DADD0>

# %%
blurred=cv2.GaussianBlur(gray_image,(21,21),0)

# %%
inverted_blurred=255-blurred
pencil=cv2.divide(gray_image,inverted_blurred,scale=256.0)
cv2_imshow(pencil)
# Out:
# <PIL.Image.Image image mode=L size=1000x800 at 0x7F289FEF05D0>

# %%
cv2_imshow(img)
cv2_imshow(pencil)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x800 at 0x7F289FE75310>
# <PIL.Image.Image image mode=L size=1000x800 at 0x7F289FE75810>
